# %% [markdown]
# Name: Chris Andrei Irag
#
# Section: DS4A
#
# Date: August 30, 2025

# %% [markdown]
# <em><font size=4>**Instructions**</font></em>: Follow the tasks or answer the questions. Show the complete code how you arrived at the answers to the questions.

# %% [markdown]
# 1. Import the Necessary Packages

# %%
# ---- Excel CSV ---- #
import pandas as pd

# ---- SQL ----- #
import sqlite3
from sqlalchemy import create_engine

# ---- Misc. ---- #
import os
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# 2. Extract the necessary files
#
#
# <font size="1px"><b>&nbsp;&nbsp;&nbsp;&nbsp;Optional: use OS to check</b></font>

# %% [markdown]
# &nbsp;&nbsp;2.1. Extract your data from the CSV and Excel

# %% [markdown]
# For CSV:
#
# - use CleanedKaggleDataSets
#
# For Excel:
#
# - use OfficeData
#
# For Database:
#
# - use world.sqlite3

# %% [markdown]
# ----
# <b><i> CSV File </b></i>
#
# ----

# %%
from pathlib import Path
NOTEBOOK_DIR = Path().resolve()
ROOT_DIR = NOTEBOOK_DIR.parent
EXTERNAL_DATA_DIR = ROOT_DIR / 'data' / 'external'

csv_path = EXTERNAL_DATA_DIR / 'CleanedKaggleDataSets.csv'
csv = pd.read_csv(csv_path)

# %%
csv
# Out:
#                                                   title Usability_index  \
# 0     Salary Prediction Data - Simple linear regression  Usability 10.0
# 1                      Heart Disease Prediction Dataset  Usability 10.0
# 2     Time Series Air Quality Data of India (2010-2023)  Usability 10.0
# 3                                 Water Quality Testing   Usability 9.4
# 4                            Multiple Sclerosis Disease  Usability 10.0
# ...                                                 ...             ...
# 9709                     Pubmed Knowledge Graph Dataset   Usability 9.4
# 9710                                World War 2 archive   Usability 9.4
# 9711  Greatest artists dataset Grammys | Billboard | RS  Usability 10.0
# 9712                                         paw_models   Usability 1.9
# 9713                      Bengali Sign Language Dataset   Usability 7.5
#
#       up_vote                   author     Updation_timeline
# 0          31  Krishnaraj_DataScience    Updated 12 days ago
# 1          31  Krishnaraj_DataScience    Updated 12 days ago
# 2          31  Krishnaraj_DataScience    Updated 12 days ago
# 3          31  Krishnaraj_DataScience    Updated 12 days ago
# 4          31  Krishnaraj_DataScience    Updated 12 days ago
# ...       ...                      ...                   ...
# 9709      124        Jose Berengueres    Updated 6 years ago
# 9710      124        Jose Berengueres    Updated 6 years ago
# 9711      124        Jose Berengueres    Updated 6 years ago
# 9712      124        Jose Berengueres    Updated 6 years ago
# 9713      124        Jose Berengueres    Updated 6 years ago
#
# [9714 rows x 5 columns]

# %% [markdown]
# **Use the .info() method to find out how many entries there are.**

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9714 entries, 0 to 9713
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              9714 non-null   object
#  1   Usability_index    9712 non-null   object
#  2   up_vote            9714 non-null   int64
#  3   author             9714 non-null   object
#  4   Updation_timeline  9714 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 379.6+ KB

# %% [markdown]
# **How many datasets are there that are related to the 'Heart'?**

# %%
counter = 0
for row in csv.itertuples():
    if "heart" in row[1].lower():
        counter += 1
print(f"Number of datasets with 'heart' in the title: {counter}")
# Out:
# Number of datasets with 'heart' in the title: 59

# %% [markdown]
# **Are there Null Values in the column Usability_index?**

# %%
has_null = csv["Usability_index"].isnull().sum() > 0
print(f"Are there any null values in the 'Usability_index' column? {has_null}")
# Out:
# Are there any null values in the 'Usability_index' column? True

# %% [markdown]
# **Show all rows with a Usability_index of 10.0**

# %%
csv.query('`Usability_index` == "Usability 10.0"')
# Out:
#                                                   title Usability_index  \
# 0     Salary Prediction Data - Simple linear regression  Usability 10.0
# 1                      Heart Disease Prediction Dataset  Usability 10.0
# 2     Time Series Air Quality Data of India (2010-2023)  Usability 10.0
# 4                            Multiple Sclerosis Disease  Usability 10.0
# 5            2023 Car Model Dataset - All Data You Need  Usability 10.0
# ...                                                 ...             ...
# 9699                                    Rohingya Survey  Usability 10.0
# 9701                           Microsoft Malware Sample  Usability 10.0
# 9702                  Software Project Management Tools  Usability 10.0
# 9706        Twitter Data - Indian General Election 2019  Usability 10.0
# 9711  Greatest artists dataset Grammys | Billboard | RS  Usability 10.0
#
#       up_vote                   author     Updation_timeline
# 0          31  Krishnaraj_DataScience    Updated 12 days ago
# 1          31  Krishnaraj_DataScience    Updated 12 days ago
# 2          31  Krishnaraj_DataScience    Updated 12 days ago
# 4          31  Krishnaraj_DataScience    Updated 12 days ago
# 5          31  Krishnaraj_DataScience    Updated 12 days ago
# ...       ...                      ...                   ...
# 9699      124        Jose Berengueres    Updated 6 years ago
# 9701      124        Jose Berengueres    Updated 6 years ago
# 9702      124        Jose Berengueres    Updated 6 years ago
# 9706      124        Jose Berengueres    Updated 6 years ago
# 9711      124        Jose Berengueres    Updated 6 years ago
#
# [2611 rows x 5 columns]

# %% [markdown]
# **Get all rows with highest upvotes**
#
# <font size='1px'><i>Bonus: Sort by Usability_index</i>

# %%
csv.sort_values(by="up_vote", ascending=False).head(20).sort_values(by="Usability_index")
# Out:
#                                                  title Usability_index  \
# 632               Music & Mental Health Survey Results  Usability 10.0
# 639        Animal Image Dataset (90 Different Animals)  Usability 10.0
# 636                                 Fake News football  Usability 10.0
# 644     Predict students' dropout and academic success  Usability 10.0
# 629             Salary data - Simple linear regression   Usability 3.5
# 641                         clip-interrogator-models-X   Usability 3.8
# 635                       Real estate price prediction   Usability 4.7
# 643                               Adult income dataset   Usability 5.9
# 628                        Crop Recommendation Dataset   Usability 5.9
# 633                     Chronic KIdney Disease dataset   Usability 7.1
# 646                                 Netflix Prize data   Usability 7.6
# 642                                   IPL_2023_Dataset   Usability 7.6
# 630                          World University Rankings   Usability 7.9
# 645    Stable Diffusion 100k Custom Prompts and Images   Usability 8.2
# 634                            New York Stock Exchange   Usability 8.5
# 637                                            CalCOFI   Usability 8.5
# 627                                 Rice Image Dataset   Usability 8.8
# 631                  Top Universities Computer Science   Usability 9.4
# 638  Earning and Loan Repayment in US Four Year Col...   Usability 9.4
# 640                                 Volcanoes on Venus   Usability 9.4
#
#      up_vote        author    Updation_timeline
# 632     1697  Murat KOKLU    Updated a year ago
# 639     1697  Murat KOKLU    Updated a year ago
# 636     1697  Murat KOKLU    Updated a year ago
# 644     1697  Murat KOKLU    Updated a year ago
# 629     1697  Murat KOKLU    Updated a year ago
# 641     1697  Murat KOKLU    Updated a year ago
# 635     1697  Murat KOKLU    Updated a year ago
# 643     1697  Murat KOKLU    Updated a year ago
# 628     1697  Murat KOKLU    Updated a year ago
# 633     1697  Murat KOKLU    Updated a year ago
# 646     1697  Murat KOKLU    Updated a year ago
# 642     1697  Murat KOKLU    Updated a year ago
# 630     1697  Murat KOKLU    Updated a year ago
# 645     1697  Murat KOKLU    Updated a year ago
# 634     1697  Murat KOKLU    Updated a year ago
# 637     1697  Murat KOKLU    Updated a year ago
# 627     1697  Murat KOKLU    Updated a year ago
# 631     1697  Murat KOKLU    Updated a year ago
# 638     1697  Murat KOKLU    Updated a year ago
# 640     1697  Murat KOKLU    Updated a year ago

# %% [markdown]
# ----
# <b><i> Excel Files </b></i>
#
# ----

# %% [markdown]
# **Get all the sheets First**

# %%
sheet_path = EXTERNAL_DATA_DIR / 'OfficeData.xlsx'

sheets = pd.ExcelFile(sheet_path)
sheets.sheet_names
# Out:
# ['Employees', 'Department', 'HRData']

# %%
sheets = 
sheets.sheet_names
# Out:
# ['Employees', 'Department', 'HRData']

# %% [markdown]
# **Get the Sheet where there are Employees Name**

# %%
xlsx = sheets.parse('HRData')
xlsx.head()
# Out:
#    ID           Employee  Gender Birth Date  Hire Date Termination Date  \
# 0   1    Harley Matthews  Female 1989-08-17 2011-10-02              NaT
# 1   2      Aliyah Thomas  Female 1988-03-27 2012-03-22       2015-05-01
# 2   3  Madeleine Bradley  Female 1981-04-18 2012-08-24       2016-06-19
# 3   4  Gabrielle Gardner  Female 2002-10-31 2012-11-12              NaT
# 4   5         Molly Owen  Female 1979-10-22 2013-09-18              NaT
#
#   Termination Reason               Education                Position  \
# 0                NaN      Higher Certificate           Administrator
# 1   Unfair Dismissal      Higher Certificate                  Lawyer
# 2        Resignation  Bachelor's Incompleted  Administrative Analyst
# 3                NaN    Bachelor's Completed      Accounting Analyst
# 4                NaN    Bachelor's Completed        Database Analyst
#
#              Department
# 0  Finance / Accounting
# 1                 Legal
# 2  Finance / Accounting
# 3  Finance / Accounting
# 4              Strategy

# %% [markdown]
# **How many Males and Females are there?**

# %%
xlsx["Gender"].value_counts()
# Out:
# Gender
# Male      56
# Female    34
# Name: count, dtype: int64

# %%
# Out:
# Gender
# Male      56
# Female    34
# Name: count, dtype: int64

# %% [markdown]
# **List all the Reasons of why some employee's are terminated**

# %%
xlsx["Termination Reason"].unique()
# Out:
# array([nan, 'Unfair Dismissal', 'Resignation', 'Dismissal',
#        'Mutual Agreement', 'End of Internishp Contract'], dtype=object)

# %%
# Out:
# array([nan, 'Unfair Dismissal', 'Resignation', 'Dismissal',
#        'Mutual Agreement', 'End of Internishp Contract'], dtype=object)

# %% [markdown]
# **Show all rows with Unfair Dismissal as the reason of their Termination**

# %%
xlsx.query('`Termination Reason` == "Unfair Dismissal"')
# Out:
#     ID         Employee  Gender Birth Date  Hire Date Termination Date  \
# 1    2    Aliyah Thomas  Female 1988-03-27 2012-03-22       2015-05-01
# 6    7       Winnie May  Female 1992-11-16 2014-04-26       2017-10-07
# 16  17        Aya Perry  Female 1990-03-18 2016-01-06       2016-07-04
# 21  22      Flora Parry  Female 1983-11-16 2016-07-24       2018-08-03
# 38  39   Jonah Thompson    Male 1995-03-23 2012-10-08       2017-05-20
# 39  40     Ethan Fisher    Male 1980-01-29 2013-10-17       2018-03-16
# 48  49    Spencer Ellis    Male 1996-08-31 2015-06-05       2017-06-05
# 66  67      Tobias John    Male 1983-01-28 2017-01-18       2019-03-09
# 71  72  Jasper Richards    Male 1978-04-12 2017-10-07       2019-06-30
# 73  74      Zain Fraser    Male 1975-01-30 2018-01-30       2018-08-03
#
#    Termination Reason               Education                   Position  \
# 1    Unfair Dismissal      Higher Certificate                     Lawyer
# 6    Unfair Dismissal    Bachelor's Completed      Communication Analyst
# 16   Unfair Dismissal  Bachelor's Incompleted          Pogrammer Analyst
# 21   Unfair Dismissal                 Major's           Database Analyst
# 38   Unfair Dismissal            Postgraduate   Administrative Assistant
# 39   Unfair Dismissal            Postgraduate                  Developer
# 48   Unfair Dismissal    Bachelor's Completed    Market Research Analyst
# 66   Unfair Dismissal            Postgraduate            Systems Analyst
# 71   Unfair Dismissal      Higher Certificate  Technical Support Analyst
# 73   Unfair Dismissal    Bachelor's Completed       Commercial Assistant
#
#                   Department
# 1                      Legal
# 6                  Marketing
# 16               Development
# 21                  Strategy
# 38      Finance / Accounting
# 39               Development
# 48                     Sales
# 66               Development
# 71  Technology and Equipment
# 73                     Sales

# %% [markdown]
# **In regards to the previous task, How many Males and Females are there?**

# %%
xlsx.query('`Termination Reason` == "Unfair Dismissal"')["Gender"].value_counts()
# Out:
# Gender
# Male      6
# Female    4
# Name: count, dtype: int64

# %% [markdown]
# **Show only the Employee, Position, and Department Columns**
#
# <font size='1px'><i>Bonus: Sort by Employee</i>

# %%
xlsx[["Employee", "Position", "Department"]].sort_values(by="Employee")
# Out:
#             Employee                  Position            Department
# 55      Albi Simpson  Administrative Assistant  Finance / Accounting
# 84       Alby Foster           Systems Analyst           Development
# 13  Alexandra Fraser              Test Analyst           Development
# 1      Aliyah Thomas                    Lawyer                 Legal
# 8   Anayah Armstrong         Marketing Analyst             Marketing
# ..               ...                       ...                   ...
# 27     Victoria Reid                 Developer           Development
# 68   Vinnie Davidson           Systems Analyst           Development
# 6         Winnie May     Communication Analyst             Marketing
# 73       Zain Fraser      Commercial Assistant                 Sales
# 82    Zakariya Mills           Systems Analyst           Development
#
# [90 rows x 3 columns]

# %% [markdown]
# ----
# &nbsp;&nbsp;2.2. Extract your data from the Database

# %%
# --- Connect to the database --- #
'''
    For this portion, use the try - except method to 
    verify if you are connected to the database
'''

DB = EXTERNAL_DATA_DIR / 'world.sqlite3'

try:
    cnx = create_engine('sqlite:///' + str(DB))
    print("Connected to database", cnx)
except Exception as e:
    print("Error connecting to database:", e)
# Out:
# Connected to database Engine(sqlite:////home/iragca/Documents/github/DS411-Predictive-Analytics/data/external/world.sqlite3)

# %% [markdown]
# **Show all the tables within the database**

# %%
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", cnx)
# Out:
#               name
# 0           cities
# 1  sqlite_sequence
# 2        countries
# 3          regions
# 4           states
# 5       subregions

# %% [markdown]
# **Show the cities table**

# %%
db = pd.read_sql('SELECT * FROM cities', cnx)
db
# Out:
#             id              name  state_id state_code  country_id  \
# 0            1  Andorra la Vella       488         07           6
# 1            2           Arinsal       493         04           6
# 2            3           Canillo       489         02           6
# 3            4         El Tarter       489         02           6
# 4            5            Encamp       487         03           6
# ...        ...               ...       ...        ...         ...
# 150677  153769           Húsavík      5231         SA          72
# 150678  153770               Hov      5233         SU          72
# 150679  153771            Fámjin      5233         SU          72
# 150680  153772            Skúvoy      5231         SA          72
# 150681  153773            Fugloy      5230         NO          72
#
#        country_code  latitude  longitude           created_at  \
# 0                AD  42.50779    1.52109  2019-10-05 23:58:06
# 1                AD  42.57205    1.48453  2019-10-05 23:58:06
# 2                AD  42.56760    1.59756  2019-10-05 23:58:06
# 3                AD  42.57952    1.65362  2019-10-05 23:58:06
# 4                AD  42.53474    1.58014  2019-10-05 23:58:06
# ...             ...       ...        ...                  ...
# 150677           FO  61.90120   -6.84560  2024-07-07 13:32:29
# 150678           FO  61.45670   -6.89010  2024-07-07 13:32:29
# 150679           FO  61.45670   -6.89010  2024-07-07 13:32:29
# 150680           FO  61.98760   -6.76540  2024-07-07 13:32:29
# 150681           FO  62.45670   -6.72340  2024-07-07 13:32:29
#
#                  updated_at  flag wikiDataId
# 0       2019-10-05 23:58:06     1      Q1863
# 1       2019-10-05 23:58:06     1     Q24554
# 2       2019-10-05 23:58:06     1     Q24554
# 3       2019-10-05 23:58:06     1     Q24413
# 4       2019-10-05 23:58:06     1     Q24413
# ...                     ...   ...        ...
# 150677  2024-07-07 13:35:50     1       None
# 150678  2024-07-07 13:35:50     1       None
# 150679  2024-07-07 13:35:50     1       None
# 150680  2024-07-07 13:35:50     1       None
# 150681  2024-07-07 13:35:50     1       None
#
# [150682 rows x 12 columns]

# %% [markdown]
# **Show the countries table**

# %%
db_ = pd.read_sql('SELECT * FROM countries', cnx)
db_
# Out:
#       id                       name iso3 numeric_code iso2 phonecode  \
# 0      1                Afghanistan  AFG          004   AF        93
# 1      2              Aland Islands  ALA          248   AX   +358-18
# 2      3                    Albania  ALB          008   AL       355
# 3      4                    Algeria  DZA          012   DZ       213
# 4      5             American Samoa  ASM          016   AS    +1-684
# ..   ...                        ...  ...          ...  ...       ...
# 245  246                     Zambia  ZMB          894   ZM       260
# 246  247                   Zimbabwe  ZWE          716   ZW       263
# 247  248                     Kosovo  XKX          926   XK       383
# 248  249                    Curaçao  CUW          531   CW       599
# 249  250  Sint Maarten (Dutch part)  SXM          534   SX      1721
#
#          capital currency                  currency_name currency_symbol  tld  \
# 0          Kabul      AFN                 Afghan afghani               ؋  .af
# 1      Mariehamn      EUR                           Euro               €  .ax
# 2         Tirana      ALL                   Albanian lek             Lek  .al
# 3        Algiers      DZD                 Algerian dinar              دج  .dz
# 4      Pago Pago      USD                      US Dollar               $  .as
# ..           ...      ...                            ...             ...  ...
# 245       Lusaka      ZMW                 Zambian kwacha              ZK  .zm
# 246       Harare      ZWL                Zimbabwe Dollar               $  .zw
# 247     Pristina      EUR                           Euro               €  .xk
# 248   Willemstad      ANG  Netherlands Antillean guilder               ƒ  .cw
# 249  Philipsburg      ANG  Netherlands Antillean guilder               ƒ  .sx
#
#                   native    region  region_id        subregion  subregion_id  \
# 0              افغانستان      Asia        3.0    Southern Asia          14.0
# 1                  Åland    Europe        4.0  Northern Europe          18.0
# 2              Shqipëria    Europe        4.0  Southern Europe          16.0
# 3                الجزائر    Africa        1.0  Northern Africa           1.0
# 4         American Samoa   Oceania        5.0        Polynesia          22.0
# ..                   ...       ...        ...              ...           ...
# 245               Zambia    Africa        1.0   Eastern Africa           4.0
# 246             Zimbabwe    Africa        1.0   Eastern Africa           4.0
# 247  Republika e Kosovës    Europe        4.0   Eastern Europe          15.0
# 248              Curaçao  Americas        2.0        Caribbean           7.0
# 249         Sint Maarten  Americas        2.0        Caribbean           7.0
#
#           nationality                                          timezones  \
# 0              Afghan  [{"zoneName":"Asia/Kabul","gmtOffset":16200,"g...
# 1        Aland Island  [{"zoneName":"Europe/Mariehamn","gmtOffset":72...
# 2           Albanian   [{"zoneName":"Europe/Tirane","gmtOffset":3600,...
# 3            Algerian  [{"zoneName":"Africa/Algiers","gmtOffset":3600...
# 4     American Samoan  [{"zoneName":"Pacific/Pago_Pago","gmtOffset":-...
# ..                ...                                                ...
# 245           Zambian  [{"zoneName":"Africa/Lusaka","gmtOffset":7200,...
# 246        Zimbabwean  [{"zoneName":"Africa/Harare","gmtOffset":7200,...
# 247  Kosovar, Kosovan  [{"zoneName":"Europe/Belgrade","gmtOffset":360...
# 248         Curacaoan  [{"zoneName":"America/Curacao","gmtOffset":-14...
# 249      Sint Maarten  [{"zoneName":"America/Anguilla","gmtOffset":-1...
#
#                                           translations   latitude   longitude  \
# 0    {"kr":"아프가니스탄","pt-BR":"Afeganistão","pt":"Afe...  33.000000   65.000000
# 1    {"kr":"올란드 제도","pt-BR":"Ilhas de Aland","pt":"...  60.116667   19.900000
# 2    {"kr":"알바니아","pt-BR":"Albânia","pt":"Albânia",...  41.000000   20.000000
# 3    {"kr":"알제리","pt-BR":"Argélia","pt":"Argélia","...  28.000000    3.000000
# 4    {"kr":"아메리칸사모아","pt-BR":"Samoa Americana","pt"... -14.333333 -170.000000
# ..                                                 ...        ...         ...
# 245  {"kr":"잠비아","pt-BR":"Zâmbia","pt":"Zâmbia","nl... -15.000000   30.000000
# 246  {"kr":"짐바브웨","pt-BR":"Zimbabwe","pt":"Zimbabué... -20.000000   30.000000
# 247              {"kr":"코소보","cn":"科索沃","tr":"Kosova"}  42.561291   20.340304
# 248  {"kr":"퀴라소","pt-BR":"Curaçao","pt":"Curaçao","...  12.116667  -68.933333
# 249  {"kr":"신트마르턴","pt-BR":"Sint Maarten","pt":"São...  18.033333  -63.050000
#
#     emoji           emojiU           created_at           updated_at  flag  \
# 0      🇦🇫  U+1F1E6 U+1F1EB  2018-07-21 09:11:03  2023-08-08 23:04:58     1
# 1      🇦🇽  U+1F1E6 U+1F1FD  2018-07-21 09:11:03  2023-08-08 23:04:58     1
# 2      🇦🇱  U+1F1E6 U+1F1F1  2018-07-21 09:11:03  2023-08-08 23:04:58     1
# 3      🇩🇿  U+1F1E9 U+1F1FF  2018-07-21 09:11:03  2023-08-08 23:04:58     1
# 4      🇦🇸  U+1F1E6 U+1F1F8  2018-07-21 09:11:03  2023-08-08 23:04:58     1
# ..    ...              ...                  ...                  ...   ...
# 245    🇿🇲  U+1F1FF U+1F1F2  2018-07-21 09:11:03  2023-08-09 21:23:19     1
# 246    🇿🇼  U+1F1FF U+1F1FC  2018-07-21 09:11:03  2023-08-09 21:23:19     1
# 247    🇽🇰  U+1F1FD U+1F1F0  2020-08-16 04:33:50  2023-08-11 17:46:28     1
# 248    🇨🇼  U+1F1E8 U+1F1FC  2020-10-26 02:54:20  2023-08-11 17:45:55     1
# 249    🇸🇽  U+1F1F8 U+1F1FD  2020-12-06 01:03:39  2023-08-09 21:23:19     1
#
#     wikiDataId
# 0         Q889
# 1         None
# 2         Q222
# 3         Q262
# 4         None
# ..         ...
# 245       Q953
# 246       Q954
# 247      Q1246
# 248     Q25279
# 249     Q26273
#
# [250 rows x 27 columns]

# %% [markdown]
# **Show the subregion table**

# %%
db_1 = pd.read_sql('SELECT * FROM subregions', cnx)
db_1
# Out:
#     id                       name  \
# 0    1            Northern Africa
# 1    2              Middle Africa
# 2    3             Western Africa
# 3    4             Eastern Africa
# 4    5            Southern Africa
# 5    6           Northern America
# 6    7                  Caribbean
# 7    8              South America
# 8    9            Central America
# 9   10               Central Asia
# 10  11               Western Asia
# 11  12               Eastern Asia
# 12  13         South-Eastern Asia
# 13  14              Southern Asia
# 14  15             Eastern Europe
# 15  16            Southern Europe
# 16  17             Western Europe
# 17  18            Northern Europe
# 18  19  Australia and New Zealand
# 19  20                  Melanesia
# 20  21                 Micronesia
# 21  22                  Polynesia
#
#                                          translations  region_id  \
# 0   {"korean":"북아프리카","portuguese":"Norte de Áfric...          1
# 1   {"korean":"중앙아프리카","portuguese":"África Centra...          1
# 2   {"korean":"서아프리카","portuguese":"África Ocident...          1
# 3   {"korean":"동아프리카","portuguese":"África Orienta...          1
# 4   {"korean":"남아프리카","portuguese":"África Austral...          1
# 5   {"korean":"북미","portuguese":"América Setentrio...          2
# 6   {"korean":"카리브","portuguese":"Caraíbas","dutch...          2
# 7   {"korean":"남아메리카","portuguese":"América do Sul...          2
# 8   {"korean":"중앙아메리카","portuguese":"América Centr...          2
# 9   {"korean":"중앙아시아","portuguese":"Ásia Central",...          3
# 10  {"korean":"서아시아","portuguese":"Sudoeste Asiáti...          3
# 11  {"korean":"동아시아","portuguese":"Ásia Oriental",...          3
# 12  {"korean":"동남아시아","portuguese":"Sudeste Asiáti...          3
# 13  {"korean":"남아시아","portuguese":"Ásia Meridional...          3
# 14  {"korean":"동유럽","portuguese":"Europa de Leste"...          4
# 15  {"korean":"남유럽","portuguese":"Europa meridiona...          4
# 16  {"korean":"서유럽","portuguese":"Europa Ocidental...          4
# 17  {"korean":"북유럽","portuguese":"Europa Setentrio...          4
# 18  {"korean":"오스트랄라시아","portuguese":"Australásia"...          5
# 19  {"korean":"멜라네시아","portuguese":"Melanésia","du...          5
# 20  {"korean":"미크로네시아","portuguese":"Micronésia","...          5
# 21  {"korean":"폴리네시아","portuguese":"Polinésia","du...          5
#
#              created_at           updated_at  flag wikiDataId
# 0   2023-08-14 07:11:03  2023-08-24 20:10:23     1     Q27381
# 1   2023-08-14 07:11:03  2023-08-24 20:22:09     1     Q27433
# 2   2023-08-14 07:11:03  2023-08-24 20:22:09     1      Q4412
# 3   2023-08-14 07:11:03  2023-08-24 20:22:10     1     Q27407
# 4   2023-08-14 07:11:03  2023-08-24 20:22:10     1     Q27394
# 5   2023-08-14 07:11:03  2023-08-24 20:22:10     1   Q2017699
# 6   2023-08-14 07:11:03  2023-08-24 20:22:10     1    Q664609
# 7   2023-08-14 07:11:03  2023-08-24 20:22:10     1        Q18
# 8   2023-08-14 07:11:03  2023-08-24 20:22:11     1     Q27611
# 9   2023-08-14 07:11:03  2023-08-24 20:22:11     1     Q27275
# 10  2023-08-14 07:11:03  2023-08-24 20:22:11     1     Q27293
# 11  2023-08-14 07:11:03  2023-08-24 20:22:11     1     Q27231
# 12  2023-08-14 07:11:03  2023-08-24 20:22:12     1     Q11708
# 13  2023-08-14 07:11:03  2023-08-24 20:22:12     1    Q771405
# 14  2023-08-14 07:11:03  2023-08-24 20:22:12     1     Q27468
# 15  2023-08-14 07:11:03  2023-08-24 20:22:12     1     Q27449
# 16  2023-08-14 07:11:03  2023-08-24 20:22:12     1     Q27496
# 17  2023-08-14 07:11:03  2023-08-24 20:22:13     1     Q27479
# 18  2023-08-14 07:11:03  2023-08-24 20:22:13     1     Q45256
# 19  2023-08-14 07:11:03  2023-08-24 20:22:13     1     Q37394
# 20  2023-08-14 07:11:03  2023-08-24 20:22:13     1   Q3359409
# 21  2023-08-14 07:11:03  2023-08-24 20:22:13     1     Q35942

# %% [markdown]
# **Bonus:** Select the data from the "countries" table, specifically for the Philippines, without creating a Pandas DataFrame.

# %%
from sqlalchemy import text

with cnx.connect() as connection:
    result = connection.execute(text("SELECT * FROM countries WHERE name = 'Philippines'"))

result.fetchall()
# Out:
# [(174, 'Philippines', 'PHL', '608', 'PH', '63', 'Manila', 'PHP', 'Philippine peso', '₱', '.ph', 'Pilipinas', 'Asia', 3, 'South-Eastern Asia', 13, 'Philippine, Filipino', '[{"zoneName":"Asia/Manila","gmtOffset":28800,"gmtOffsetName":"UTC+08:00","abbreviation":"PHT","tzName":"Philippine Time"}]', '{"kr":"필리핀","pt-BR":"Filipinas","pt":"Filipinas","nl":"Filipijnen","hr":"Filipini","fa":"جزایر الندفیلیپین","de":"Philippinen","es":"Filipinas","fr":"Philippines","ja":"フィリピン","it":"Filippine","cn":"菲律宾","tr":"Filipinler"}', 13, 122, '🇵🇭', 'U+1F1F5 U+1F1ED', '2018-07-21 09:11:03', '2023-08-11 17:45:55', 1, 'Q928')]
